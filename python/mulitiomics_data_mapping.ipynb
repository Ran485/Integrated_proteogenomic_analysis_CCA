# %%
import pandas as pd
import numpy as np
import os

# %%
clinical_data = pd.read_csv("/Volumes/Samsung_T5/downloads/CCA/CCA_mapping_data/clinical_merge20220406.csv", index_col=0)
clinical_data.columns
# Out:
# Index(['clinical', 'time', 'time_day', 'status', 'T_pathological_subtype',
#        'NAT_pathological_subtype', 'iCCA_Pathology', 'age', 'gender', 'E/I',
#        'iCC_eCC', 'firT', 'gene_T', 'phos_T', 'phos_T_firmiana', 'firN',
#        'gene_N', 'phos_N', 'RNA_T', 'RNA_N', 'phos_N_firmiana', 'PT', 'HBsAg',
#        'HBcAb', 'HBV', 'GGT', 'ALT', 'Tbil', 'CA199', 'Cholelithiasis_1',
#        'Type_2_diabetes', 'Hypertension', 'Presence_of_fluke_infection',
#        'Perineural_invasion', 'Lymphovascular_invasion', 'G', 'S', 'F', 'T',
#        'N', 'M', 'Stage', 'eccStage', 'iccStage', 'Grade', 'Age', 'Gender',
#        'Pathology', 'Proteome_Subtype', 'Tumor_Sample_Barcode', 'total_perMB',
#        'log2_TMB', 'Sig1', 'Sig2', 'Sig3', 'Sig4', '6p22.2 _Amp', '6q14.3_Del',
#        '1q21.2_Amp', '6p21.2_Del', 'fir_T1', 'StromalScore', 'ImmuneScore',
#        'ESTIMATEScore', 'TumorPurity', 'ImmuneScore_Xcell',
#        'StromaScore_Xcell', 'MicroenvironmentScore_Xcell', 'Gene_ID',
# ...

# %%
multiomics_index = ['firT', 'gene_T', 'phos_T', 'phos_T_firmiana', 'firN',
       'gene_N', 'phos_N', 'RNA_T', 'RNA_N', 'phos_N_firmiana']

# %%
mapping_index = pd.read_csv("/Volumes/Samsung_T5/downloads/Integrated_multiomics_analysis_CCA/data/metadata/mapping_index.csv",index_col = 0)
mapping_index = pd.merge(mapping_index, clinical_data, left_index = True, right_index = True, how = "left")
mapping_index
# Out:
#          iCC_eCC_x  clinical       time  time_day  status  \
# CCA_No
# CCA#32           1  14S25615  49.033333    1471.0     0.0
# CCA#33           1  14S26078  32.466667     974.0     1.0
# CCA#34           1  14S26209  47.500000    1425.0     0.0
# CCA#36           1  14S27582  23.466667     704.0     1.0
# CCA#37           1  14S28082  62.500000    1875.0     0.0
# ...            ...       ...        ...       ...     ...
# CCA#206          2  18S11211  18.733333     562.0     1.0
# CCA#207          2  18S11765   9.600000     288.0     1.0
# CCA#210          2  18S32905  12.933333     388.0     1.0
# CCA#215          2  18S42281  10.033333     301.0     1.0
# CCA#216          2  18S53535   1.066667      32.0     1.0
#
#         T_pathological_subtype NAT_pathological_subtype iCCA_Pathology  age  \
# CCA_No
# CCA#32          5-1+5-2+L+N(S)                      111        smallBD   66
# CCA#33               5-1(N)(S)                      210        smallBD   33
# ...

# %%
RNA_Tumor = pd.read_csv("/Volumes/Samsung_T5/downloads/Integrated_multiomics_analysis_CCA/data/metadata/RNA_T_del50%.csv",index_col = 0)
RNA_Tumor = RNA_Tumor.T
RNA_Tumor
# Out:
#                             A1BG   A1BG-AS1       A1CF         A2M  \
# R21023766_F13_15_15     2.482263   0.000000   2.342859   54.270782
# R21023768_F13_17_17    14.801243   1.489376   8.167996   61.212448
# R21023770_F13_19_19     2.950100   0.000000   6.482440  243.597229
# R21023774_F13_23_23    19.177736   3.615062  10.636040  130.583313
# R21023776_F13_25_25    16.759157   0.527375   8.092555   31.598635
# ...                          ...        ...        ...         ...
# R21026762_F19_1_189     0.000000   0.000000   1.031801  103.614319
# R21026759_F18_29_187    0.924745   0.946679   1.043208  110.388741
# R21026755_F18_25_183    1.819281   1.956194   0.227003   82.351791
# R21026749_F18_19_177    2.498373   0.945840   0.404908   71.024300
# count                 102.000000  77.000000  98.000000  123.000000
#
#                           A4GALT        AAAS        AACS      AADAC  \
# R21023766_F13_15_15     4.338752   11.018165    2.937222   3.576416
# ...

# %%
mapping_index = pd.merge(mapping_index, RNA_Tumor, left_index = True, right_index = True, how = "left")
mapping_index
# Out:
#          iCC_eCC_x  clinical       time  time_day  status  \
# CCA_No
# CCA#32           1  14S25615  49.033333    1471.0     0.0
# CCA#33           1  14S26078  32.466667     974.0     1.0
# CCA#34           1  14S26209  47.500000    1425.0     0.0
# CCA#36           1  14S27582  23.466667     704.0     1.0
# CCA#37           1  14S28082  62.500000    1875.0     0.0
# ...            ...       ...        ...       ...     ...
# CCA#206          2  18S11211  18.733333     562.0     1.0
# CCA#207          2  18S11765   9.600000     288.0     1.0
# CCA#210          2  18S32905  12.933333     388.0     1.0
# CCA#215          2  18S42281  10.033333     301.0     1.0
# CCA#216          2  18S53535   1.066667      32.0     1.0
#
#         T_pathological_subtype NAT_pathological_subtype iCCA_Pathology  age  \
# CCA_No
# CCA#32          5-1+5-2+L+N(S)                      111        smallBD   66
# CCA#33               5-1(N)(S)                      210        smallBD   33
# ...
